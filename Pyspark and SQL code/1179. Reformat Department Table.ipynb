# %% [markdown]
# # 1179. Reformat Department Table
#
# ### Reformat the table such that there is a department id column and a revenue column for each month.
#
# ### Return the result table in any order.

# %%
# %sql
SELECT 
  id, 
  MAX(CASE WHEN month = 'Jan' THEN revenue END) AS Jan_Revenue,
  MAX(CASE WHEN month = 'Feb' THEN revenue END) AS Feb_Revenue,
  MAX(CASE WHEN month = 'Mar' THEN revenue END) AS Mar_Revenue,
  MAX(CASE WHEN month = 'Apr' THEN revenue END) AS Apr_Revenue,
  MAX(CASE WHEN month = 'May' THEN revenue END) AS May_Revenue,
  MAX(CASE WHEN month = 'Jun' THEN revenue END) AS Jun_Revenue,
  MAX(CASE WHEN month = 'Jul' THEN revenue END) AS Jul_Revenue,
  MAX(CASE WHEN month = 'Aug' THEN revenue END) AS Aug_Revenue,
  MAX(CASE WHEN month = 'Sep' THEN revenue END) AS Sep_Revenue,
  MAX(CASE WHEN month = 'Oct' THEN revenue END) AS Oct_Revenue,
  MAX(CASE WHEN month = 'Nov' THEN revenue END) AS Nov_Revenue,
  MAX(CASE WHEN month = 'Dec' THEN revenue END) AS Dec_Revenue
FROM Department
GROUP BY id;

# %%
from pyspark.sql import functions as F

df = spark.table('workspace.default.department')

result = df.groupBy("id").agg(
    F.max(F.when(F.col("month") == "Jan", F.col("revenue"))).alias("Jan_Revenue"),
    F.max(F.when(F.col("month") == "Feb", F.col("revenue"))).alias("Feb_Revenue"),
    F.max(F.when(F.col("month") == "Mar", F.col("revenue"))).alias("Mar_Revenue"),
    F.max(F.when(F.col("month") == "Apr", F.col("revenue"))).alias("Apr_Revenue"),
    F.max(F.when(F.col("month") == "May", F.col("revenue"))).alias("May_Revenue"),
    F.max(F.when(F.col("month") == "Jun", F.col("revenue"))).alias("Jun_Revenue"),
    F.max(F.when(F.col("month") == "Jul", F.col("revenue"))).alias("Jul_Revenue"),
    F.max(F.when(F.col("month") == "Aug", F.col("revenue"))).alias("Aug_Revenue"),
    F.max(F.when(F.col("month") == "Sep", F.col("revenue"))).alias("Sep_Revenue"),
    F.max(F.when(F.col("month") == "Oct", F.col("revenue"))).alias("Oct_Revenue"),
    F.max(F.when(F.col("month") == "Nov", F.col("revenue"))).alias("Nov_Revenue"),
    F.max(F.when(F.col("month") == "Dec", F.col("revenue"))).alias("Dec_Revenue")
)


display(result)

# %%
# %sql
CREATE OR REPLACE TABLE Department (
    id      INT,
    revenue INT,
    month   VARCHAR(3),
    PRIMARY KEY (id, month)
);



INSERT INTO Department (id, revenue, month) VALUES
-- Department 1: has data for most months
(1, 8000,  'Jan'),
(1, 7000,  'Feb'),
(1, 6000,  'Mar'),
(1, 9000,  'Apr'),
(1, 5000,  'May'),
(1, 11000, 'Jun'),
(1, 13000, 'Jul'),
(1, 8500,  'Aug'),

-- Department 2: only a few months (tests NULLs)
(2, 9000,  'Jan'),
(2, 4000,  'Mar'),
(2, 7500,  'Sep'),

-- Department 3: scattered months
(3, 10000, 'Feb'),
(3, 12000, 'Jun'),
(3, 15000, 'Nov'),
(3, 3000,  'Dec'),

-- Department 4: only one month (lots of NULLs)
(4, 20000, 'Jul'),

-- Department 5: all 12 months (tests a full row)
(5, 1000,  'Jan'),
(5, 2000,  'Feb'),
(5, 3000,  'Mar'),
(5, 4000,  'Apr'),
(5, 5000,  'May'),
(5, 6000,  'Jun'),
(5, 7000,  'Jul'),
(5, 8000,  'Aug'),
(5, 9000,  'Sep'),
(5, 10000, 'Oct'),
(5, 11000, 'Nov'),
(5, 12000, 'Dec');

# %%
# %sql
SELECT * FROM department
